# %% [markdown]
# # Create database; scrape data; store scraped data and state population data as two tables

# %%
import requests
from bs4 import BeautifulSoup
import re
import sqlite3
from time import sleep
from random import randint
import pandas as pd

# %%
def create_storage():
    """This function creates our Metal_Bands db and Band_Info table."""
    
    # connect to sqlite
    conn = sqlite3.connect('Metal_Bands.db')
    cursor = conn.cursor()

    # create band_info table
    cursor.execute("""CREATE TABLE BAND_INFO(
                        Band_Name text,
                        Status text,
                        Location text,
                        Year_Formed text,
                        Genre text,
                        Lyrical_Themes text,
                        Years_Active text)""")
    conn.commit()
    conn.close()

# %%
def scrape(url):
    """This function takes the given url and iterates through each tab of bands, scraping 
        each band page for its data. The data is stored in the Metal_Bands database."""
    
    # connect to sqlite db
    conn = sqlite3.connect('Metal_Bands.db')
    cursor = conn.cursor()
    
    # loop over each tab of band links
    for i in range(72):
        # get html of tab webpage (session deals with cookies?)
        session = requests.Session()
        response = session.get(url, 
                           headers={'User-Agent': 'Mozilla/5.0'})

        # "prettify" html code
        soup = BeautifulSoup(response.content, "html.parser")
        
        # get all the band links
        links = [link.get("href") for link in soup.find_all("a")]
            
        # rest
        sleep(randint(3,5))
            
        # scrape each link
        for j in range(len(links)):
            
            # get html of band page
            session = requests.Session()
            response = session.get(links[j], headers={'User-Agent': 'Mozilla/5.0'})

            # "prettify" html code
            soup = BeautifulSoup(response.content, "html.parser")
            
            # get band data
            band_name = soup.select("h1.band_name")[0].get_text()
            band_info = soup.select("div#band_stats")[0].get_text()
            
            location = re.search(r"(?<=Location:\n).*", band_info).group(0)
            status = re.search(r"(?<=Status:\n).*", band_info).group(0)
            year_formed = re.search(r"(?<=Formed in:\n).*", band_info).group(0)
            genre = re.search(r"(?<=Genre:\n).*", band_info).group(0)
            lyrical_themes = re.search(r"(?<=Lyrical themes:\n).*", band_info).group(0)
            years_active = band_info.split(":")[-1].strip("\n").strip()
            
            # insert data into sqlite db
            row = (band_name, status, location, year_formed, genre, lyrical_themes, years_active)
            cursor.execute("INSERT INTO BAND_INFO VALUES (?,?,?,?,?,?,?)", row)
            conn.commit()
            
            # rest
            sleep(randint(3,5))
            
        # update url to be that of next tab
        echo = re.search(r"(?<=Echo=)\d+", url)
        echo = str(int(echo.group(0)) + 1)
        url = re.sub(r"(?<=Echo=)\d+", echo, url)
        
        disp_start = re.search(r"(?<=iDisplayStart=)\d+", url)
        disp_start = str(int(disp_start.group(0)) + 500)
        url = re.sub(r"(?<=iDisplayStart=)\d+", disp_start, url)

        last_arg = re.search(r"\d+$", url)
        last_arg = str(int(last_arg.group(0)) + 1)
        url = re.sub(r"\d+$", last_arg, url)
        
        # indicate which tabs are complete
        print("Tab done:", i)
        
    # close connection to db
    conn.close()

# %%
# run em... don't do this again!
url = "https://www.metal-archives.com/browse/ajax-country/c/US/json/1?sEcho=1&iColumns=4&sColumns=&iDisplayStart=0&iDisplayLength=500&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&iSortCol_0=0&sSortDir_0=asc&iSortingCols=1&bSortable_0=true&bSortable_1=true&bSortable_2=true&bSortable_3=false&_=1668986854743"
#create_storage()
#scrape(url)
# Out:
# Tab done: 0
# Tab done: 1
# Tab done: 2
# Tab done: 3
# Tab done: 4
# Tab done: 5
# Tab done: 6
# Tab done: 7
# Tab done: 8
# Tab done: 9
# Tab done: 10
# Tab done: 11
# Tab done: 12
# Tab done: 13
# Tab done: 14
# Tab done: 15
# Tab done: 16
# Tab done: 17
# Tab done: 18
# Tab done: 19
# Tab done: 20
# Tab done: 21
# Tab done: 22
# Tab done: 23
# Tab done: 24
# Tab done: 25
# Tab done: 26
# Tab done: 27
# Tab done: 28
# Tab done: 29
# Tab done: 30
# Tab done: 31
# Tab done: 32
# Tab done: 33
# Tab done: 34
# Tab done: 35
# Tab done: 36
# Tab done: 37
# Tab done: 38
# Tab done: 39
# Tab done: 40
# Tab done: 41
# Tab done: 42
# Tab done: 43
# Tab done: 44
# Tab done: 45
# Tab done: 46
# Tab done: 47
# Tab done: 48
# Tab done: 49
# Tab done: 50
# Tab done: 51
# Tab done: 52
# Tab done: 53
# Tab done: 54
# Tab done: 55
# Tab done: 56
# Tab done: 57
# Tab done: 58
# Tab done: 59
# Tab done: 60
# Tab done: 61
# Tab done: 62
# Tab done: 63
# Tab done: 64
# Tab done: 65
# Tab done: 66
# Tab done: 67
# Tab done: 68
# Tab done: 69
# Tab done: 70
# Tab done: 71

# %%
# check if worked...DONE!
conn = sqlite3.connect('Metal_Bands.db')
cursor = conn.cursor()

data = cursor.execute("SELECT * FROM BAND_INFO")
#conn.close()
i = 0
num_rows = 0
for row in data:
    if i < 100:
        print(row)
    i += 1
    num_rows += 1
conn.close()
print(num_rows)
# Out:
# ('۞', 'Split-up', 'N/A', 'N/A', 'Black Metal', 'N/A', 'N/A')
# ('...and Here I Lie', 'Split-up', 'Holley, New York', '1994', 'Death/Doom Metal', 'Depression, Isolation, Suicide', '1994-2000,\n2007')
# ('...and They Will Meet God', 'Split-up', 'Palestine, Texas', '2002', 'Melodic Death Metal/Crossover', 'Doom, Death, Hate', '2002-?')
# ('...in Agony of the Eclipsed Moon', 'Active', 'Midland City, Alabama', 'N/A', 'Black Metal/Dark Ambient', 'N/A', 'N/A')
# ('...Under a Full Moon', 'Active', 'Midland, Michigan (early); North Carolina, United States / Norway (later)', '2017', 'Black/Doom Metal', 'Depression, Suicide, Anti-capitalism', '2016-2017  (as Disrhythmia),\n2017-present')
# ('.357', 'Split-up', 'Jackson, Mississippi', '2004', 'Black Metal/Grindcore', 'N/A', '2004-2006')
# ('.44 Caliber Killers', 'Unknown', 'Syracuse, New York', '2001', 'Thrash Metal/Punk/Crossover', 'Flaws, Serial killers, Pizza, Politics, Humour', '2001-?')
# ('.50Cal Facial Fracture', 'Active', 'Philadelphia, Pennsylvania', '2020', 'Slam/Brutal Death Metal', 'N/A', '2020 (as 50calibectomy),\n 2020-present')
# ('.Nema', 'Split-up', 'Detroit, Michigan', '1995', 'Black Metal/Crust', 'Misanthropy, Anti-Capitalism', '1995-1999')
# ('.springofdrownedpanda.', 'Unknown', 'Peekskill, New York', 'N/A', 'Sludge/Doom Metal', 'Ranma 1/2, Negative thoughts', 'N/A')
# ("'Big Jim' Shively", 'Active', 'Nashville, Tennessee', 'N/A', 'Doom Metal/Psychedelic Rock', 'N/A', 'N/A')
# ("'Iisnááhí", 'Active', 'Albuquerque, New Mexico', '2018', 'Black Metal', "Navajo/Native American mythology, Diné Bahane', Genocide, History", '2018-present')
# ("('M') Inc.", 'Unknown', 'Apopka/Orlando, Florida', '2009', 'Death Metal', 'N/A', '2009 (as Massacre Inc.),\n2009-?')
# ('((Thorlock))', 'Active', 'Cape Girardeau, Missouri', '2007', 'Sludge/Stoner Metal', 'N/A', '2007-present')
# ('(god-rot)', 'Unknown', 'Rochester, New York', '2005', 'Progressive Death Metal/Grindcore', 'Gore, Self-destruction', '2005-?')
# ('(Lone) Wolf & Cub', 'Split-up', 'Chicago, Illinois', '2003', 'Progressive Metalcore', 'N/A', '2003-2005 (as Wolf and Cub),\n2005-?')
# ('(Origin Unknown)', 'Split-up', 'Ashburn/Sterling, Virginia', '1998', 'Metalcore/Crossover', 'N/A', '1998-2003,\n2004-?')
# ('(Rabbit)', 'Active', 'Boston, Massachusetts', '2010', 'Drone/Doom Metal', 'Instrumental', '2010-present')
# ('(sic)', 'Split-up', 'Minneapolis, Minnesota', '1993', 'Death Metal', 'N/A', '1993-1996')
# ('(waning)', 'Split-up', 'Sacramento, California', '2007', 'Dark Ambient (early); Doom/Post-Metal (later)', 'Sorrow, Love, Nature, Death', '2007-2018')
# ('[Omitted]', 'Unknown', 'Los Angeles, California', '2006', 'Death Metal/Grindcore', 'Murder, Insanity', '2006-2015')
# ('[Sworn]', 'Active', 'Weslaco, Texas', '2007', 'Black Metal/Industrial', 'Death, Technology, Corruption', '2007-present')
# ('[v.ę.r.ż]', 'Active', 'Seattle, Washington', 'N/A', 'Sludge/Post-Metal', 'N/A', 'N/A')
# ('~Lair~', 'Unknown', 'Mission, Texas', '2011', 'Avant-garde Black Metal', 'N/A', '2011-?')
# ('$Greed$', 'On hold', 'Los Angeles, California', '1992', 'Heavy/Thrash Metal', 'Politics, Humanity', '1992-1994 (as Simon Le Greed),\n1994-1996 (as Greed),\n1999-?')
# ('$lamboy$', 'Active', 'Cary, Illinois', '2016', 'Death Metal/Grindcore (early); Slam/Brutal Death Metal (later)', 'Memes, Nonsense', '2016-2017,\n2017-present')
# ('$lutrot', 'Split-up', 'Nevada / North Carolina / Texas', '2013', 'Slam/Brutal Death Metal', 'Gore', '2013-2015,\n2017-2019')
# ('0% Hate', 'Active', 'Las Vegas, Nevada', '2016', 'Technical Death Metal', 'N/A', '2016-present')
# ('00', 'Active', 'New Jersey', 'N/A', 'Stoner/Doom Metal/Rock', 'N/A', 'N/A')
# ('1 Body 6 Graves', 'Active', 'Converse, Indiana', 'N/A', 'Death Metal', 'N/A', 'N/A')
# ('1:34', 'Split-up', 'Bedford/Bloomington, Indiana', '2010', 'Melodic Death Metal', 'Gore, War, Pirates', '2010-2016')
# ('10 Kingdoms', 'Changed name', 'Dallas, Texas', '1998', 'Thrash/Heavy Metal', 'Anti-religion', '1998-2015,\n2015-? (as Blackwolfe)')
# ('10-67 P.D.O.A.', 'Active', 'Minneapolis, Minnesota', '1993', 'Heavy Metal', 'N/A', '1993-present')
# ('10:13', 'Active', 'California', '2019', 'Psychedelic/Experimental Black Metal', 'Instrumental', '2019-present')
# ('100 Suns', 'Active', 'San Francisco, California', '2004', 'Death Metal', 'N/A', '2004-present')
# ('1000 A.D.', 'Changed name', 'Olympia, Washington', '2001', 'Drone/Sludge Metal', 'Christianity', '2001-?,\n?-present (as Growing)')
# ('1000 Bone Cylinder Explosion', 'Active', 'Philadelphia, Pennsylvania', 'N/A', 'Avant-garde Black/Speed Metal', 'N/A', 'N/A')
# ('1000 Yard Stare', 'Active', 'Wyandotte (early); Detroit (later), Michigan', '1998', 'Death/Groove Metal (early); Sludge/Doom/Death Metal (later)', 'Hate, Murder, Death', '1998-2001,\n2015-present')
# ('1080', 'Split-up', 'Louisville, Kentucky', '2002', 'Groove/Thrash Metal', 'N/A', '2002-2003')
# ('11:11', 'Active', 'Florida', '2005', 'Heavy/Thrash Metal', 'Politics', '2005-present')
# ('11:34', 'Active', 'London, Kentucky', '2004', 'Death/Thrash Metal', 'Hate, Violence, Death, Gore', '2004-present')
# ('1134', 'Unknown', 'Elgin, Illinois', '2002', 'Thrash/Groove Metal', 'N/A', '2002-?')
# ('1134', 'Active', 'Johnson City, Tennessee', '2014', 'Heavy/Groove/Thrash Metal', 'N/A', '2014-present')
# ('11th Plague', 'Active', 'Kokomo, Indiana', '2011', 'Groove/Thrash Metal', 'N/A', '2011-present')
# ('12 Days of Anarchy', 'Split-up', 'Rock Island, Illinois', '1998', 'Death Metal', 'Anarchy', '1998-2002')
# ('12 Days Straight', 'Active', 'Atlantic City, New Jersey', 'N/A', 'Groove Metal', 'N/A', 'N/A')
# ('12 Eyes', 'On hold', 'New York, New York', '2005', 'Sludge Metal', 'N/A', '2005-2009')
# ('12 Gauge Massacre', 'Split-up', 'Hamilton, Ohio', '2006', 'Deathcore', 'Death, Nihilism, Horror', '2006-2008')
# ('12 Ton Sledge', 'Split-up', 'Phoenix, Arizona', '1997', 'Thrash Metal', 'Tragedy', '1997-2007')
# ('12:06', 'Unknown', 'Boston, Massachusetts', '2001', 'Heavy/Power Metal', 'Strength and weakness, Personal issues', '2001-?')
# ('13', 'Split-up', 'New York, New York', '1992', 'Sludge/Doom Metal', 'Alienation, Abuse', '1990-1992 (as Thunderpussy 13),\n1992-1996')
# ('13 A.D.', 'Split-up', 'Muskegon, Michigan', 'N/A', 'Heavy Metal', 'N/A', 'N/A')
# ('13 Candles', 'Split-up', 'Dix Hills (Long Island), New York', '1991', 'Heavy Metal', 'N/A', '1991-?')
# ('13 Killings', 'Changed name', 'Orange County, California', '2004', 'Metalcore', 'N/A', '2004-2011,\n2011-present (as I, Of Helix)')
# ('13 Mag', 'Split-up', 'Hillyard/Spokane, Washington', '2010', 'Southern/Groove Metal', 'N/A', '2010-2012')
# ('13 Thrones', 'Active', 'Bay Area, California', 'N/A', 'Death Metal', 'N/A', 'N/A')
# ('13 Winters', 'Split-up', 'Hollis, Maine', '2001', 'Symphonic Black Metal', 'Pain, Life, Darkness, Relationships', '2001-2015')
# ('1369', 'Changed name', 'Evansville, Indiana', '1993', 'Thrash/Groove Metal', 'Death, Darkness', '1993-2003,\n2003-present (as Blood Tribe)')
# ('137', 'Active', 'Petoskey, Michigan / Rochester/Canandaigua, New York', '1997', 'Sludge/Doom Metal', 'Inner struggles, Mankind', '1997-present')
# ('13Down', 'Active', 'Phoenix, Arizona', '2008', 'Groove Metal', 'N/A', '2008-present')
# ('13th Cadaver', 'Changed name', 'Salt Lake City, Utah', '2006', 'Death Metal', 'Death, Gore, Undead', '2006-?,\n?-2007 (as Splatter the Cadaver),\n2008 (as Splatter the Cadaver)')
# ('13th Knot', 'Changed name', 'Fayetteville, North Carolina', '2005', 'Heavy/Power Metal', 'N/A', '2005-?,\n?-present (as Romeo Falls)')
# ('13th Level', 'Changed name', 'Louisville, Kentucky', '2000', 'Groove/Thrash Metal/Hardcore', 'Personal grievance, Hatred', '2000-2009,\n2009-present (as Year of the Gun)')
# ('14 Sacred Words', 'Active', 'New York, New York (early); Paoli, Indiana (later)', '2015', 'Metalcore', 'National Socialism, White supremacy, Antisemitism, Society, Conspiracy theories', '2015-present')
# ('1492', 'Active', 'N/A', 'N/A', 'Black Metal', 'N/A', 'N/A')
# ('16', 'Active', 'Los Angeles, California', '1991', 'Sludge Metal', 'Drugs, Violence, Depression, Anger', '1991-2004,\n2007-present')
# ('16 Stitches', 'Active', 'Marshfield, Massachusetts', '2000', 'Progressive Rock/Metal', 'N/A', '2000-present')
# ('1733', 'Split-up', 'Dallas, Texas', '2013', 'Thrash Metal', 'N/A', '2013')
# ('1776', 'Changed name', 'N/A', 'N/A', 'Black Metal', 'N/A', '?-?,\n?-present (as Praefector)')
# ('18 Speed Tranny', 'Changed name', 'Chicago, Illinois', '1999', 'Heavy/Stoner Metal', 'Life, Women, Sex', '1999-2007,\n2007-present (as Analog Machine)')
# ('18 Wheels of Justice', 'Active', 'Boston, Massachusetts', '2002', 'Thrash Metal/Metalcore', 'N/A', '2002-present')
# ('1931', 'Split-up', 'Galloway, Ohio', 'N/A', 'Deathcore', 'Christianity, Life, Death', 'N/A')
# ('19TilDawn', 'Active', 'Battle Creek, Michigan', '2010', 'Thrash/Heavy Metal', 'N/A', '2010-present')
# ('1Enemy3', 'Active', 'Anchorage, Alaska', '2004', 'Progressive Metal', 'N/A', '2004-present')
# ('2 Headed Chang', 'Active', 'Everett, Washington', '1998', 'Thrash/Groove Metal', 'Death, Social', '1998-present')
# ('200 Stab Wounds', 'Active', 'Cleveland, Ohio', '2019', 'Death Metal', 'Death, Decay', '2019-present')
# ('20Grit', 'Active', 'San Jose, California', '1987', 'Heavy Metal/Progressive Hard Rock', 'Corruption, Personal issues', '1987-present')
# ('21 Acts of Manslaughter', 'Active', 'Eustace, Texas', 'N/A', 'Grindcore', 'N/A', 'N/A')
# ('21st Century Sin', 'Split-up', 'Saint Paul, Minnesota', '1996', 'Death/Thrash Metal', 'N/A', '1996-?')
# ('22 Spits', 'Active', 'New Hampshire', 'N/A', 'Brutal Death Metal', 'Gore', 'N/A')
# ('23 Roadkill', 'Split-up', 'Oklahoma City, Oklahoma', '1990', 'Groove Metal', 'N/A', '1990-?')
# ('237', 'Unknown', 'El Paso, Texas', '1995', 'Thrash/Groove Metal', 'Horror, Death, Sorrow, Agony', '1995-1997,\n2008-?')
# ('24Gore', 'Active', 'Stockton, California', 'N/A', 'Thrash Metal', 'N/A', 'N/A')
# ('25th Mission', 'Active', 'East Meadow (Long Island), New York', 'N/A', 'Heavy Metal', 'N/A', 'N/A')
# ('26 Beers', 'Split-up', 'Boston, Massachusetts', '2004', 'Thrash Metal/Crossover', 'N/A', '2004-2010')
# ('27 North', 'Split-up', 'Lansing, Michigan', 'N/A', 'Heavy Metal', 'N/A', 'N/A')
# ('3 Headed Monster', 'Active', 'Massachusetts', '2001', 'Progressive/Power/Thrash Metal', 'Instrumental', '2001-2009,\n2010-present')
# ('3 Headed Moses', 'Split-up', 'Columbia, Missouri', '2002', 'Heavy/Thrash/Death Metal', 'Humour, Death, Life', '2002-?')
# ('3 Headed Snake', 'Active', 'Los Angeles, California', 'N/A', 'Power/Heavy Metal', 'N/A', 'N/A')
# ('3 Minutes to Live', 'Active', 'Nashville, Tennessee', '2004', 'Groove Metal', 'Personal struggle and triumph', '2004-present')
# ('3 Parts Demon', 'Active', 'Detroit, Michigan', '2006', 'Progressive Death Metal', 'N/A', '2006-present')
# ('3 Pieces of Evil', 'Active', 'Ohio', 'N/A', 'Symphonic Black Metal', 'N/A', 'N/A')
# ('3 Times Driven', 'Split-up', 'Geraldine, Alabama (early); Albertville, Alabama (later)', '2007', 'Heavy Metal/Hard Rock', 'Christianity', '2007-2010,\n2012-2017')
# ('3-Dead', 'Active', 'Salinas, California', '2005', 'Heavy Metal', 'George W. Bush, War, Pain, Death', '2005-present')
# ('3:33', 'Active', 'Richmond, Virginia', '2015', 'Thrash Metal/Crossover', 'Cops, Murder, Fantasy', '2015-present')
# ("3's Eve", 'On hold', 'Minneapolis, Minnesota (early); New Lisbon, New Jersey (mid); Kansas City, Missouri (later)', '1996', 'Gothic Rock/Ambient, Heavy/Gothic Metal', 'N/A', '1996-?')
# ('300 Cobras', 'Split-up', 'Athens, Georgia', 'N/A', 'Thrash/Black Metal', 'N/A', 'N/A')
# ('3000psi', 'Active', 'Pismo Beach, California', '2006', 'Thrash Metal/Crossover', 'N/A', '2006-present')
# ('313', 'Split-up', 'Pittsburgh/Monroeville, Pennsylvania', '1985', 'Power/Speed/Heavy Metal', 'N/A', '1983-1985 (as Discipline),\n1985-1988')
# ('32 Mildreds', 'Split-up', 'Bowie, Maryland', 'N/A', 'Thrash Metal', 'N/A', 'N/A')
# 35879

# %%
# need to load state pop data into db now
# from: https://www.census.gov/data/tables/time-series/demo/popest/2020s-state-total.html#par_textimage_1574439295
state_data = pd.read_csv("State_Pops.csv")
state_data.set_index("State", inplace=True)

conn = sqlite3.connect("Metal_Bands.db")
cursor = conn.cursor()
state_data.to_sql(name='STATE_INFO', con=conn, index_label='State')
conn.close()

# %%
# check if worked...DONE!
conn = sqlite3.connect('Metal_Bands.db')
cursor = conn.cursor()

data = cursor.execute("SELECT * FROM STATE_INFO")
i = 0
num_rows = 0
for row in data:
    if i < 100:
        print(row)
    i += 1
    num_rows += 1
conn.close()
print(num_rows)
# Out:
# ('Alabama', '5,039,877')
# ('Alaska', '732,673')
# ('Arizona', '7,276,316')
# ('Arkansas', '3,025,891')
# ('California', '39,237,836')
# ('Colorado', '5,812,069')
# ('Connecticut', '3,605,597')
# ('Delaware', '1,003,384')
# ('Florida', '21,781,128')
# ('Georgia', '10,799,566')
# ('Hawaii', '1,441,553')
# ('Idaho', '1,900,923')
# ('Illinois', '12,671,469')
# ('Indiana', '6,805,985')
# ('Iowa', '3,193,079')
# ('Kansas', '2,934,582')
# ('Kentucky', '4,509,394')
# ('Louisiana', '4,624,047')
# ('Maine', '1,372,247')
# ('Maryland', '6,165,129')
# ('Massachusetts', '6,984,723')
# ('Michigan', '10,050,811')
# ('Minnesota', '5,707,390')
# ('Mississippi', '2,949,965')
# ('Missouri', '6,168,187')
# ('Montana', '1,104,271')
# ('Nebraska', '1,963,692')
# ('Nevada', '3,143,991')
# ('New Hampshire', '1,388,992')
# ('New Jersey', '9,267,130')
# ('New Mexico', '2,115,877')
# ('New York', '19,835,913')
# ('North Carolina', '10,551,162')
# ('North Dakota', '774,948')
# ('Ohio', '11,780,017')
# ('Oklahoma', '3,986,639')
# ('Oregon', '4,246,155')
# ('Pennsylvania', '12,964,056')
# ('Rhode Island', '1,095,610')
# ('South Carolina', '5,190,705')
# ('South Dakota', '895,376')
# ('Tennessee', '6,975,218')
# ('Texas', '29,527,941')
# ('Utah', '3,337,975')
# ('Vermont', '645,570')
# ('Virginia', '8,642,274')
# ('Washington', '7,738,692')
# ('West Virginia', '1,782,959')
# ('Wisconsin', '5,895,908')
# ('Wyoming', '578,803')
# 50

# %%
state_data["Population"]
# Out:
# State
# Alabama            5,039,877
# Alaska               732,673
# Arizona            7,276,316
# Arkansas           3,025,891
# California        39,237,836
# Colorado           5,812,069
# Connecticut        3,605,597
# Delaware           1,003,384
# Florida           21,781,128
# Georgia           10,799,566
# Hawaii             1,441,553
# Idaho              1,900,923
# Illinois          12,671,469
# Indiana            6,805,985
# Iowa               3,193,079
# Kansas             2,934,582
# Kentucky           4,509,394
# Louisiana          4,624,047
# Maine              1,372,247
# Maryland           6,165,129
# Massachusetts      6,984,723
# Michigan          10,050,811
# Minnesota          5,707,390
# Mississippi        2,949,965
# Missouri           6,168,187
# Montana            1,104,271
# Nebraska           1,963,692
# Nevada             3,143,991
# New Hampshire      1,388,992
# New Jersey         9,267,130
# New Mexico         2,115,877
# New York          19,835,913
# North Carolina    10,551,162
# North Dakota         774,948
# Ohio              11,780,017
# Oklahoma           3,986,639
# Oregon             4,246,155
# Pennsylvania      12,964,056
# Rhode Island       1,095,610
# South Carolina     5,190,705
# South Dakota         895,376
# Tennessee          6,975,218
# Texas             29,527,941
# Utah               3,337,975
# Vermont              645,570
# Virginia           8,642,274
# Washington         7,738,692
# West Virginia      1,782,959
# Wisconsin          5,895,908
# Wyoming              578,803
# Name: Population, dtype: object
